# %% [markdown]
# ### Import

# %%
import pandas as pd
import datetime as dt

pd.options.display.max_rows = 1000
pd.options.display.max_colwidth = 10000
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ### General parameters

# %%
mimiciii = "PATH TO DATA/mimic-iii(1.4)/"

# %% [markdown]
# ### Patients

# %%
patients = pd.read_csv(mimiciii + "PATIENTS.csv")

# %%
patients.head(3)

# %%
print("# all patients = ", patients.SUBJECT_ID.nunique())
print("# all patients dead in hosp = ", patients[patients.DOD_HOSP.notnull()].shape[0])
print("# all patients dead after hosp = ", patients[patients.DOD.notnull()].shape[0])
print("# all patients dead = ", patients[patients.EXPIRE_FLAG == 1].shape[0])
print(patients.GENDER.unique())
# Out:
# # all patients =  46520
# # all patients dead in hosp =  9974
# # all patients dead after hosp =  15759
# # all patients dead =  15759
# ['F' 'M']

# %% [markdown]
# ### Admission

# %%
admissions = pd.read_csv(mimiciii + "ADMISSIONS.csv")

# %%
admissions.head(3)

# %%
print("# unique patients = ", admissions.SUBJECT_ID.nunique())
print("# hospital admissions = ", admissions.HADM_ID.nunique())
print("# dead at hospital discharge= ", admissions[admissions.HOSPITAL_EXPIRE_FLAG == 1].shape[0])
print("# alive at hospital discharge = ", admissions[admissions.HOSPITAL_EXPIRE_FLAG == 0].shape[0])
# Out:
# # unique patients =  46520
# # hospital admissions =  58976
# # dead at hospital discharge=  5854
# # alive at hospital discharge =  53122

# %% [markdown]
# ### ICU Stays

# %%
icustays = pd.read_csv(mimiciii + "ICUSTAYS.csv")

# %%
icustays.head(3)

# %%
print("# unique patients = ", icustays.SUBJECT_ID.nunique())
print("# unique hospital admissions = ", icustays.HADM_ID.nunique())
print("# unique icu admissions = ", icustays.ICUSTAY_ID.nunique())
print("# unique icu transfered stays = ", icustays[icustays.FIRST_CAREUNIT != icustays.LAST_CAREUNIT].ICUSTAY_ID.nunique())
# Out:
# # unique patients =  46476
# # unique hospital admissions =  57786
# # unique icu admissions =  61532
# # unique icu transfered stays =  3833

# %% [markdown]
# ### Transfer

# %%
transfers = pd.read_csv(mimiciii + "TRANSFERS.csv")

# %%
transfers.head(3)

# %%
print("# all patients = ", transfers.SUBJECT_ID.nunique())
print("# all admissions to hospital = ", transfers.HADM_ID.nunique())
print("# all transfers = ", transfers.ROW_ID.nunique())
# Out:
# # all patients =  46520
# # all admissions to hospital =  58976
# # all transfers =  261897

# %% [markdown]
# ### Diagnoses ICD

# %%
diagnose_icd = pd.read_csv(mimiciii + "DIAGNOSES_ICD.csv")

# %%
diagnose_icd.head(3)

# %%
print("# all patients = ", diagnose_icd.SUBJECT_ID.nunique())
print("# all hospital admissions = ", diagnose_icd.HADM_ID.nunique())
# Out:
# # all patients =  46520
# # all hospital admissions =  58976

# %%
d_diagnose_icd = pd.read_csv(mimiciii + "D_ICD_DIAGNOSES.csv")

# %%
d_diagnose_icd.head(3)
# Out:
#    ROW_ID ICD9_CODE              SHORT_TITLE  \
# 0     174     01166    TB pneumonia-oth test
# 1     175     01170   TB pneumothorax-unspec
# 2     176     01171  TB pneumothorax-no exam
#
#                                                                                                                                                                           LONG_TITLE
# 0  Tuberculous pneumonia [any form], tubercle bacilli not found by bacteriological or histological examination, but tuberculosis confirmed by other methods [inoculation of animals]
# 1                                                                                                                                              Tuberculous pneumothorax, unspecified
# 2                                                                                                     Tuberculous pneumothorax, bacteriological or histological examination not done

# %%
print("# all codes = ", d_diagnose_icd.ICD9_CODE.nunique())
# Out:
# # all codes =  14567

# %% [markdown]
# ### Procedure ICD

# %%
procedure_icd = pd.read_csv(mimiciii + "PROCEDURES_ICD.csv")

# %%
procedure_icd.head(3)

# %%
print("# all patients = ", procedure_icd.SUBJECT_ID.nunique())
print("# all hospital admissions = ", procedure_icd.HADM_ID.nunique())
# Out:
# # all patients =  42214
# # all hospital admissions =  52243

# %%
d_procedure_icd = pd.read_csv(mimiciii + "D_ICD_PROCEDURES.csv")

# %%
d_procedure_icd.head(3)
# Out:
#    ROW_ID  ICD9_CODE              SHORT_TITLE  \
# 0     264        851               Canthotomy
# 1     265        852          Blepharorrhaphy
# 2     266        859  Adjust lid position NEC
#
#                          LONG_TITLE
# 0                        Canthotomy
# 1                   Blepharorrhaphy
# 2  Other adjustment of lid position

# %%
print("# all codes = ", d_procedure_icd.ICD9_CODE.nunique())
# Out:
# # all codes =  3809

# %% [markdown]
# ### Microbiologyevents

# %%
microevents = pd.read_csv(mimiciii + "MICROBIOLOGYEVENTS.csv")

# %%
microevents.head(3)

# %%
print("# all micro test orders = ", microevents.ROW_ID.nunique())
print("# unique patients = ", microevents.SUBJECT_ID.nunique())
print("# unique hospital admissions = ", microevents.HADM_ID.nunique())
print("# unique samples (specimens) = ", microevents.SPEC_ITEMID.nunique())
# Out:
# # all micro test orders =  631726
# # unique patients =  39184
# # unique hospital admissions =  48740
# # unique samples (specimens) =  92

# %% [markdown]
# ### Prescriptions

# %%
prescriptions = pd.read_csv(mimiciii + "PRESCRIPTIONS.csv")
# Out:
# <ipython-input>:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   prescriptions = pd.read_csv(mimiciii + "PRESCRIPTIONS.csv")

# %%
prescriptions.head(3)

# %%
print("# table size = ", prescriptions.shape)
print("# unique patients = ", prescriptions.SUBJECT_ID.nunique())
print("# unique hospital admissions = ", prescriptions.HADM_ID.nunique())
print("# unique icu admissions = ", prescriptions.ICUSTAY_ID.nunique())
print("# unique medication name = ", prescriptions.DRUG.nunique())
print("# unique Generic Sequence Number (GSN) = ", prescriptions.GSN.nunique())
print("# unique National Drug Code (NDC) = ", prescriptions.NDC.nunique())
# Out:
# # table size =  (4156450, 19)
# # unique patients =  39363
# # unique hospital admissions =  50216
# # unique icu admissions =  52151
# # unique medication name =  4525
# # unique Generic Sequence Number (GSN) =  4685
# # unique National Drug Code (NDC) =  4204

# %% [markdown]
# ### Labevents

# %%
labevents = pd.read_csv(mimiciii + "LABEVENTS.csv")

# %%
labevents.head(3)

# %%
print("# table size = ", labevents.shape)
print("# unique patients = ", labevents.SUBJECT_ID.nunique())
print("# unique hospital admissions = ", labevents.HADM_ID.nunique())
print("# unique Items = ", labevents.ITEMID.nunique())
# Out:
# # table size =  (27854055, 9)
# # unique patients =  46252
# # unique hospital admissions =  58151
# # unique Items =  726

# %%
d_labitems = pd.read_csv(mimiciii + "D_LABITEMS.csv")

# %%
d_labitems.head(3)
# Out:
#    ROW_ID  ITEMID            LABEL                      FLUID    CATEGORY  \
# 0     546   51346           Blasts  Cerebrospinal Fluid (CSF)  Hematology
# 1     547   51347      Eosinophils  Cerebrospinal Fluid (CSF)  Hematology
# 2     548   51348  Hematocrit, CSF  Cerebrospinal Fluid (CSF)  Hematology
#
#   LOINC_CODE
# 0    26447-3
# 1    26451-5
# 2    30398-2

# %%
print("# unique lab item = ", d_labitems.ITEMID.nunique())
print("# unique lab name = ", d_labitems.LABEL.nunique())
print("# unique lab substance = ", d_labitems.FLUID.nunique())
print("# unique lab category = ", d_labitems.CATEGORY.nunique())
# Out:
# # unique lab item =  753
# # unique lab name =  589
# # unique lab substance =  16
# # unique lab category =  6

# %% [markdown]
# ### D-items

# %%
d_items = pd.read_csv(mimiciii + "D_ITEMS.csv")

# %%
d_items.head(3)
# Out:
#    ROW_ID  ITEMID                                        LABEL ABBREVIATION  \
# 0     457     497  Patient controlled analgesia (PCA) [Inject]          NaN
# 1     458     498                            PCA Lockout (Min)          NaN
# 2     459     499                               PCA Medication          NaN
#
#   DBSOURCE      LINKSTO CATEGORY UNITNAME PARAM_TYPE  CONCEPTID
# 0  carevue  chartevents      NaN      NaN        NaN        NaN
# 1  carevue  chartevents      NaN      NaN        NaN        NaN
# 2  carevue  chartevents      NaN      NaN        NaN        NaN

# %%
print("# unique items = ", d_items.ITEMID.nunique())
print("# unique label name = ", d_items.LABEL.nunique())
print("# unique categories = ", d_items.CATEGORY.nunique())
print("links to other tables = ", d_items.LINKSTO.unique())
print("types of itemes = ", d_items.PARAM_TYPE.unique())
# Out:
# # unique items =  12487
# # unique label name =  11846
# # unique categories =  94
# links to other tables =  ['chartevents' 'datetimeevents' 'inputevents_cv' 'outputevents'
#  'inputevents_mv' 'procedureevents_mv' 'microbiologyevents']
# types of itemes =  [nan 'Solution' 'Checkbox' 'Text' 'Numeric' 'Process' 'Date time'
#  'Numeric with tag']

# %% [markdown]
# ### Chartevents

# %%
chartevents = pd.read_csv(mimiciii + "CHARTEVENTS.csv", chunksize=1000)

# %%
next(chartevents).head(3)

# %% [markdown]
# ### Datetimeevents

# %%
datetimeevents = pd.read_csv(mimiciii + "DATETIMEEVENTS.csv")
# Out:
# <ipython-input>:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   datetimeevents = pd.read_csv(mimiciii + "DATETIMEEVENTS.csv")

# %%
datetimeevents.head(3)

# %%
print("# unique patients = ", datetimeevents.SUBJECT_ID.nunique())
print("# unique hospital admissions = ", datetimeevents.HADM_ID.nunique())
print("# unique icu admissions = ", datetimeevents.ICUSTAY_ID.nunique())
print("# unique items = ", datetimeevents.ITEMID.nunique())
print("# unique types = ", datetimeevents.VALUEUOM.unique())
# Out:
# # unique patients =  29185
# # unique hospital admissions =  36218
# # unique icu admissions =  38632
# # unique items =  155
# # unique types =  ['Date' 'Date and Time']

# %% [markdown]
# ### Procedureevents_mv

# %%
procedureevents = pd.read_csv(mimiciii + "PROCEDUREEVENTS_MV.csv")

# %%
procedureevents.head(3)

# %%
print("# unique patients = ", procedureevents.SUBJECT_ID.nunique())
print("# unique hospital admissions = ", procedureevents.HADM_ID.nunique())
print("# unique icu admissions = ", procedureevents.ICUSTAY_ID.nunique())
print("# unique items = ", procedureevents.ITEMID.nunique())
print("# unique procedure events = ", procedureevents.ORDERCATEGORYNAME.nunique())
print("# procedure events = ", procedureevents.ORDERCATEGORYNAME.unique())
# Out:
# # unique patients =  17692
# # unique hospital admissions =  21894
# # unique icu admissions =  23401
# # unique items =  116
# # unique procedure events =  12
# # procedure events =  ['Procedures' 'Ventilation' 'Invasive Lines' 'Imaging' 'Peripheral Lines'
#  'Intubation/Extubation' 'Significant Events' 'Continuous Procedures'
#  'Dialysis' 'Peritoneal Dialysis' 'CRRT Filter Change' 'Communication']

# %% [markdown]
# ### Inputevents_mv

# %%
inputevents_mv = pd.read_csv(mimiciii + "INPUTEVENTS_MV.csv")

# %%
inputevents_mv.head(3)

# %%
print("# unique patients = ", inputevents_mv.SUBJECT_ID.nunique())
print("# unique hospital admissions = ", inputevents_mv.HADM_ID.nunique())
print("# unique icu admissions = ", inputevents_mv.ICUSTAY_ID.nunique())
print("# unique items = ", inputevents_mv.ITEMID.nunique())
# Out:
# # unique patients =  17680
# # unique hospital admissions =  21879
# # unique icu admissions =  23386
# # unique items =  278

# %% [markdown]
# ### Inputevents_cv

# %%
inputevents_cv = pd.read_csv(mimiciii + "INPUTEVENTS_CV.csv")
# Out:
# <ipython-input>:1: DtypeWarning: Columns (7,9,17,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   inputevents_cv = pd.read_csv(mimiciii + "INPUTEVENTS_CV.csv")

# %%
inputevents_cv.head(3)

# %%
print("# unique patients = ", inputevents_cv.SUBJECT_ID.nunique())
print("# unique hospital admissions = ", inputevents_cv.HADM_ID.nunique())
print("# unique icu admissions = ", inputevents_cv.ICUSTAY_ID.nunique())
print("# unique items = ", inputevents_cv.ITEMID.nunique())
# Out:
# # unique patients =  27124
# # unique hospital admissions =  31970
# # unique icu admissions =  33799
# # unique items =  2938

# %% [markdown]
# ### Outputevents

# %%
outputevents = pd.read_csv(mimiciii + "OUTPUTEVENTS.csv")

# %%
outputevents.head(3)

# %%
outputevents = pd.merge(outputevents, d_icuitems, on=['ITEMID'], how='left')

# %%
print("# unique patients = ", outputevents.SUBJECT_ID.nunique())
print("# unique hospital admissions = ", outputevents.HADM_ID.nunique())
print("# unique icu admissions = ", outputevents.ICUSTAY_ID.nunique())
print("# unique items = ", outputevents.ITEMID.nunique())
# Out:
# # unique patients =  41857
# # unique hospital admissions =  52008
# # unique icu admissions =  55076
# # unique items =  1155

# %% [markdown]
# ### Note

# %% [markdown]
# ### Noteevents

# %%
note = pd.read_csv(mimiciii + "NOTEEVENTS.csv")
# Out:
# <ipython-input>:1: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   note = pd.read_csv(mimiciii + "NOTEEVENTS.csv")

# %%
note.head(1)

# %%
print("# table size = ", note.shape)
print("# unique note = ", note.ROW_ID.nunique())
print("# unique patients = ", note.SUBJECT_ID.nunique())
print("# unique hospital admissions = ", note.HADM_ID.nunique())
print("# note types = ", note.CATEGORY.unique())
# Out:
# # table size =  (2083180, 11)
# # unique note =  2083180
# # unique patients =  46146
# # unique hospital admissions =  58361
# # note types =  ['Discharge summary' 'Echo' 'ECG' 'Nursing' 'Physician ' 'Rehab Services'
#  'Case Management ' 'Respiratory ' 'Nutrition' 'General' 'Social Work'
#  'Pharmacy' 'Consult' 'Radiology' 'Nursing/other']

# %%
print(note[note.ROW_ID == 174].TEXT[0])
